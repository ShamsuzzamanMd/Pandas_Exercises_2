# %% [markdown]
# An academic task

# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv(url, delimiter="\t")
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo[chipo["item_price"]>"$10.00"]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# 14           7         1                    Chips and Guacamole
# ...

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
chipo_two_cols =chipo[["item_name","item_price"]]
chipo_two_cols.head()
# Out:
#                                item_name item_price
# 0           Chips and Fresh Tomato Salsa     $2.39
# 1                                   Izze     $3.39
# 2                       Nantucket Nectar     $3.39
# 3  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                           Chicken Bowl    $16.98

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo_two_cols.sort_values("item_name")
# Out:
#               item_name item_price
# 3389  6 Pack Soft Drink    $12.98
# 341   6 Pack Soft Drink     $6.49
# 1849  6 Pack Soft Drink     $6.49
# 1860  6 Pack Soft Drink     $6.49
# 2713  6 Pack Soft Drink     $6.49
# 3422  6 Pack Soft Drink     $6.49
# 553   6 Pack Soft Drink     $6.49
# 1916  6 Pack Soft Drink     $6.49
# 1922  6 Pack Soft Drink     $6.49
# 1937  6 Pack Soft Drink     $6.49
# 3836  6 Pack Soft Drink     $6.49
# 298   6 Pack Soft Drink     $6.49
# 1976  6 Pack Soft Drink     $6.49
# 1167  6 Pack Soft Drink     $6.49
# 3875  6 Pack Soft Drink     $6.49
# 1124  6 Pack Soft Drink     $6.49
# 3886  6 Pack Soft Drink     $6.49
# 2108  6 Pack Soft Drink     $6.49
# 3010  6 Pack Soft Drink     $6.49
# 4535  6 Pack Soft Drink     $6.49
# 4169  6 Pack Soft Drink     $6.49
# 4174  6 Pack Soft Drink     $6.49
# 4527  6 Pack Soft Drink     $6.49
# 4522  6 Pack Soft Drink     $6.49
# 3806  6 Pack Soft Drink     $6.49
# 2389  6 Pack Soft Drink     $6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo[["quantity","item_price","item_name"]].sort_values("item_price", ascending=False)
# Out:
#       quantity item_price              item_name
# 2624         1     $9.39        Steak Salad Bowl
# 4419         1     $9.39        Steak Salad Bowl
# 4036         1     $9.39        Steak Salad Bowl
# 1825         1     $9.39     Barbacoa Salad Bowl
# 3115         1     $9.39     Carnitas Salad Bowl
# 4547         1     $9.39        Steak Salad Bowl
# 3098         1     $9.39        Steak Salad Bowl
# 4241         1     $9.39        Steak Salad Bowl
# 1418         1     $9.39     Barbacoa Salad Bowl
# 4391         1     $9.39        Steak Salad Bowl
# 4572         1     $9.39        Steak Salad Bowl
# 2600         1     $9.39        Steak Salad Bowl
# 607          1     $9.39        Steak Salad Bowl
# 4390         1     $9.39     Barbacoa Salad Bowl
# 1865         1     $9.39     Carnitas Salad Bowl
# 1421         1     $9.39     Barbacoa Salad Bowl
# 3356         1     $9.39     Barbacoa Salad Bowl
# 1789         1     $9.25     Carnitas Soft Tacos
# ...

# %% [markdown]
# ### Step 8. How many times were a Veggie Salad Bowl ordered?

# %%
v_g_salad = chipo[chipo["item_name"]=="Veggie Salad Bowl"]
v_g_salad["item_name"].count()
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times people orderd more than one Canned Soda?

# %%
chipo_soda_count = chipo[chipo["item_name"]=="Canned Soda"]
chipo_soda_count.count()
# Out:
# order_id              104
# quantity              104
# item_name             104
# choice_description    104
# item_price            104
# dtype: int64

# %%
chipo[(chipo["item_name"]=="Canned Soda") & (chipo["quantity"]>1)]["quantity"].count()
# Out:
# 20
